# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
data = pd.read_csv("AutomobileDataset.csv")

# %%
data
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
data.isnull().sum()
# Out:
# name            0
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
data['brand'] = data['name'].apply(lambda x: x.split()[0])
data["brand"].value_counts()
# Out:
# brand
# ford             51
# chevrolet        43
# plymouth         31
# amc              28
# dodge            28
# toyota           25
# datsun           23
# buick            17
# pontiac          16
# volkswagen       15
# honda            13
# mercury          11
# mazda            10
# oldsmobile       10
# fiat              8
# peugeot           8
# audi              7
# chrysler          6
# vw                6
# volvo             6
# renault           5
# saab              4
# subaru            4
# opel              4
# chevy             3
# bmw               2
# cadillac          2
# maxda             2
# mercedes-benz     2
# triumph           1
# vokswagen         1
# mercedes          1
# hi                1
# capri             1
# chevroelt         1
# toyouta           1
# nissan            1
# Name: count, dtype: int64

# %%
data["name"].value_counts()
# Out:
# name
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: count, Length: 305, dtype: int64

# %%
data["mpg"].value_counts()
# Out:
# mpg
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: count, Length: 129, dtype: int64

# %%
data["cylinders"].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
data["model_year"].value_counts()
# Out:
# model_year
# 73    40
# 78    36
# 76    34
# 82    31
# 75    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
data[data["name"] == "toyota corolla"]
# Out:
#                name   mpg  cylinders  displacement  horsepower  weight  \
# 167  toyota corolla  29.0          4          97.0        75.0    2171
# 205  toyota corolla  28.0          4          97.0        75.0    2155
# 321  toyota corolla  32.2          4         108.0        75.0    2265
# 356  toyota corolla  32.4          4         108.0        75.0    2350
# 382  toyota corolla  34.0          4         108.0        70.0    2245
#
#      acceleration  model_year origin   brand
# 167          16.0          75  japan  toyota
# 205          16.4          76  japan  toyota
# 321          15.2          80  japan  toyota
# 356          16.8          81  japan  toyota
# 382          16.9          82  japan  toyota

# %%
data["origin"].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
# Creating plot
fig = plt.figure(figsize=(8, 4))
plt.pie(data["origin"].value_counts(), labels = data["origin"].value_counts().keys() , autopct="%1.1f%%")
 
# show plot
plt.title("Percentage of car labels")
plt.show()

# %%
data[data["horsepower"] > 200].sort_values(ascending = False, by = "horsepower")
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 116            pontiac grand prix  16.0          8         400.0       230.0
# 8                pontiac catalina  14.0          8         455.0       225.0
# 13        buick estate wagon (sw)  14.0          8         455.0       225.0
# 95       buick electra 225 custom  12.0          8         455.0       225.0
# 6                chevrolet impala  14.0          8         454.0       220.0
# 7               plymouth fury iii  14.0          8         440.0       215.0
# 25                      ford f250  10.0          8         360.0       215.0
# 94   chrysler new yorker brougham  13.0          8         440.0       215.0
# 27                     dodge d200  11.0          8         318.0       210.0
# 67                mercury marquis  11.0          8         429.0       208.0
#
#      weight  acceleration  model_year origin      brand
# 116    4278           9.5          73    usa    pontiac
# ...

# %%
data[data["model_year"] > 81]
# Out:
#                                   name   mpg  cylinders  displacement  \
# 367                 chevrolet cavalier  28.0          4         112.0
# 368           chevrolet cavalier wagon  27.0          4         112.0
# 369          chevrolet cavalier 2-door  34.0          4         112.0
# 370         pontiac j2000 se hatchback  31.0          4         112.0
# 371                     dodge aries se  29.0          4         135.0
# 372                    pontiac phoenix  27.0          4         151.0
# 373               ford fairmont futura  24.0          4         140.0
# 374                     amc concord dl  23.0          4         151.0
# 375                volkswagen rabbit l  36.0          4         105.0
# 376                 mazda glc custom l  37.0          4          91.0
# 377                   mazda glc custom  31.0          4          91.0
# 378             plymouth horizon miser  38.0          4         105.0
# ...

# %%
data.sort_values(ascending=False, by="mpg")
# Out:
#                      name   mpg  cylinders  displacement  horsepower  weight  \
# 322             mazda glc  46.6          4          86.0        65.0    2110
# 329   honda civic 1500 gl  44.6          4          91.0        67.0    1850
# 325  vw rabbit c (diesel)  44.3          4          90.0        48.0    2085
# 394             vw pickup  44.0          4          97.0        52.0    2130
# 326    vw dasher (diesel)  43.4          4          90.0        48.0    2335
# ..                    ...   ...        ...           ...         ...     ...
# 103      chevrolet impala  11.0          8         400.0       150.0    4997
# 67        mercury marquis  11.0          8         429.0       208.0    4633
# 25              ford f250  10.0          8         360.0       215.0    4615
# 26              chevy c20  10.0          8         307.0       200.0    4376
# 28               hi 1200d   9.0          8         304.0       193.0    4732
#
# ...

# %%
plt.scatter(data['weight'], data['mpg'], color = "red")
plt.title("MPG-Weight Scatter Chart")
plt.xlabel("Weight")
plt.ylabel("MPG")
# Out:
# Text(0, 0.5, 'MPG')

# %%
plt.scatter(data["horsepower"], data["acceleration"], color="green")
plt.xlabel("Horsepower")
plt.ylabel("Acceleration")
# Out:
# Text(0, 0.5, 'Acceleration')

# %%
top10_acceleration = data.sort_values(ascending=False, by="acceleration").head(10)

# %%
top10_acceleration
# Out:
#                                   name   mpg  cylinders  displacement  \
# 299                        peugeot 504  27.2          4         141.0
# 394                          vw pickup  44.0          4          97.0
# 326                 vw dasher (diesel)  43.4          4          90.0
# 59                   volkswagen type 3  23.0          4          97.0
# 300  oldsmobile cutlass salon brougham  23.9          8         260.0
# 195                 chevrolet chevette  29.0          4          85.0
# 196                    chevrolet woody  24.5          4          98.0
# 209                        peugeot 504  19.0          4         120.0
# 328                 mercedes-benz 240d  30.0          4         146.0
# 325               vw rabbit c (diesel)  44.3          4          90.0
#
#      horsepower  weight  acceleration  model_year  origin          brand
# 299        71.0    3190          24.8          79  europe        peugeot
# ...

# %%
data
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin      brand
# ...

# %%
fig = plt.figure(figsize=(30, 10))
plt.bar(data["brand"].value_counts().keys(), data["brand"].value_counts(), color = "red")
plt.title("Number of Production by Brands")
plt.xlabel("Brand")
plt.ylabel("Numbers")
# Out:
# Text(0, 0.5, 'Numbers')

# %%
average_mpg_origin = data.groupby("origin")["mpg"].mean()

# %%
average_mpg_origin
# Out:
# origin
# europe    27.891429
# japan     30.450633
# usa       20.083534
# Name: mpg, dtype: float64

# %%
plt.bar(average_mpg_origin.keys(), average_mpg_origin.values)
plt.title("Average MPG of Origins")
plt.xlabel("Brands")
plt.ylabel("Average MPG")
# Out:
# Text(0, 0.5, 'Average MPG')

# %%
average_weight_origin = data.groupby("origin")["weight"].mean()

# %%
average_weight_origin
# Out:
# origin
# europe    2423.300000
# japan     2221.227848
# usa       3361.931727
# Name: weight, dtype: float64

# %%
plt.bar(average_weight_origin.index, average_weight_origin.values)
plt.title("Average Weight")
plt.xlabel("Origin")
plt.ylabel("Average Weight")
# Out:
# Text(0, 0.5, 'Average Weight')

# %%
average_acceleration = data.groupby("origin")["acceleration"].mean()

# %%
average_acceleration
# Out:
# origin
# europe    16.787143
# japan     16.172152
# usa       15.033735
# Name: acceleration, dtype: float64

# %%
average_horsepower = data.groupby("origin")["horsepower"].mean()
average_horsepower
# Out:
# origin
# europe     80.558824
# japan      79.835443
# usa       119.048980
# Name: horsepower, dtype: float64

# %%
origin_informations = {
    "Average Horsepower" : (average_horsepower["usa"], average_horsepower["japan"], average_horsepower["europe"]),
    "Average Acceleration" : (average_acceleration["usa"], average_acceleration["japan"] , average_acceleration["europe"]), 
}


x = np.arange(len(data["origin"].value_counts()))  # the Brand locations
width = 0.15  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in origin_informations.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

    
ax.set_xlabel('Origins')
ax.set_title('Horsepowers and Accelerations Comparision')
ax.set_xticks(x + width/2, data["origin"].value_counts().index)
ax.legend(loc='upper right', ncols=2)
ax.set_ylim(0, 130) 
plt.show()

# %%
average_horsepower
# Out:
# origin
# europe     80.558824
# japan      79.835443
# usa       119.048980
# Name: horsepower, dtype: float64

# %%
average_acceleration
# Out:
# origin
# europe    16.787143
# japan     16.172152
# usa       15.033735
# Name: acceleration, dtype: float64
